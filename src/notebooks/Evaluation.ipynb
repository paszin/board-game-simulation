# %%
import os
os.chdir("..")

import random
import matplotlib.pyplot as plt

from GameSimulation import Card, CardStack, Player, GameState, Game


stack = CardStack("Draw Pile", [Card(number=i) for i in range(2, 100)])

# %%
stack[0], stack[97]
# Out:
# (|99|, |2|)

# %%
rate = 0
stack.cards.reverse()
for i, card in enumerate(stack.cards, start=2):
    print(i, card)
    rate += min(abs(i-card.number), abs(101-i-card.number))

# stack.cards
# Out:
# 2 |99|
# 3 |98|
# 4 |97|
# 5 |96|
# 6 |95|
# 7 |94|
# 8 |93|
# 9 |92|
# 10 |91|
# 11 |90|
# 12 |89|
# 13 |88|
# 14 |87|
# 15 |86|
# 16 |85|
# 17 |84|
# 18 |83|
# 19 |82|
# 20 |81|
# 21 |80|
# 22 |79|
# 23 |78|
# 24 |77|
# 25 |76|
# 26 |75|
# 27 |74|
# 28 |73|
# 29 |72|
# 30 |71|
# 31 |70|
# 32 |69|
# 33 |68|
# 34 |67|
# 35 |66|
# 36 |65|
# 37 |64|
# 38 |63|
# 39 |62|
# 40 |61|
# 41 |60|
# 42 |59|
# 43 |58|
# 44 |57|
# 45 |56|
# 46 |55|
# 47 |54|
# 48 |53|
# 49 |52|
# 50 |51|
# 51 |50|
# 52 |49|
# 53 |48|
# 54 |47|
# 55 |46|
# 56 |45|
# 57 |44|
# 58 |43|
# 59 |42|
# 60 |41|
# 61 |40|
# 62 |39|
# 63 |38|
# 64 |37|
# 65 |36|
# 66 |35|
# 67 |34|
# 68 |33|
# 69 |32|
# 70 |31|
# 71 |30|
# 72 |29|
# 73 |28|
# 74 |27|
# 75 |26|
# 76 |25|
# 77 |24|
# 78 |23|
# 79 |22|
# 80 |21|
# 81 |20|
# 82 |19|
# 83 |18|
# 84 |17|
# 85 |16|
# 86 |15|
# 87 |14|
# 88 |13|
# 89 |12|
# 90 |11|
# 91 |10|
# 92 |9|
# 93 |8|
# 94 |7|
# 95 |6|
# 96 |5|
# 97 |4|
# 98 |3|
# 99 |2|

# %%
# Out:
# 190

# %%
random.shuffle(stack.cards)
plt.scatter(x=list(range(len(stack.cards))), y=[c.number for c in stack.cards])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-824642ac19b9> in <module>
# ----> 1 random.shuffle(stack.cards)
#       2 plt.scatter(x=list(range(len(stack.cards))), y=[c.number for c in stack.cards])
#       3
#
# NameError: name 'random' is not defined

# %%
plt.plot([c.number for c in stack.cards])
